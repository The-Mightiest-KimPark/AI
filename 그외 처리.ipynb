# %%
# !nvidia-smi
# Out:
# Thu Dec 17 15:29:12 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   78C    P0    40W /  70W |  14816MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------------
# absl-py                            0.11.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-project                   0.8.3
# argh                               0.26.2
# asgiref                            3.3.1
# asn1crypto                         1.3.0
# astor                              0.8.1
# astroid                            2.4.2
# astropy                            4.0
# atomicwrites                       1.3.0
# attrs                              19.3.0
# Automat                            20.2.0
# autopep8                           1.4.4
# autovizwidget                      0.16.0
# Babel                              2.8.0
# backcall                           0.1.0
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.8.2
# bitarray                           1.2.1
# ...

# %%
# Out:
# Found existing installation: tensorflow 1.15.3
# Uninstalling tensorflow-1.15.3:
#   Would remove:
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/estimator_ckpt_converter
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/freeze_graph
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/saved_model_cli
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/tensorboard
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/tf_upgrade_v2
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/tflite_convert
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/toco
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/bin/toco_from_protos
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/_solib_k8/_U@mkl_Ulinux_S_S_Cmkl_Ulibs_Ulinux___Uexternal_Smkl_Ulinux_Slib/libiomp5.so
#     /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/_solib_k8/_U@mkl_Ulinux_S_S_Cmkl_Ulibs_Ulinux___Uexternal_Smkl_Ulinux_Slib/libmklml_intel.so
# ...

# %%
import pandas as pd
import numpy as np

out_boxes = np.array([[204.28265,   13.994211, 316.00397,  366.59967 ],
 [146.36028,    8.872647, 233.04659,  381.75977 ],
 [ 98.01218,   32.856873, 164.96313,  353.60635 ],
 [429.8967,   249.55536,  458.45834,  407.47452 ],
 [408.48178,  250.72658,  436.9835,   407.09335 ],
 [441.18607,   -2.296233, 478.81253,   97.54785 ],
 [393.86957,  250.27644,  422.74567,  406.40652 ]])

coords = []
x_coords  = (out_boxes[:,0] + out_boxes[:,2])/2
y_coords  = (out_boxes[:,1] + out_boxes[:,3])/2

names = ['squash ', 'apple ', 'squash ', 'carrot ', 'squash ', 'squash ', 'squash ']

df = pd.DataFrame({'id':[5, 2, 5, 3, 5, 5, 5], 'name': names, 'x_coord':x_coords, 'y_coord':y_coords})

name_unq = df['name'].unique()
id_unq = df['id'].unique()
print(name_unq, id_unq)
my_result = [{'id': print_unq[j], 'name' : name_unq[j], 'count': 0, 'coordindate' : [] } for j in range(name_unq.shape[0])]


for i in range(df.shape[0]):
    for j in range(len(my_result)):
        if my_result[j]['name'] == df.iloc[i,0]:
            my_result[j]['count'] += 1
            my_result[j]['coordindate'].append( list(df.iloc[i,:][1:3]  ))
            break

for dct in my_result:
    dct['coordindate'] = '{}'.format(dct['coordindate'])
            
print(my_result)
display(df)
# Out:
# ['squash ' 'apple ' 'carrot '] [5 2 3]
# [{'id': 5, 'name': 'squash ', 'count': 0, 'coordindate': '[]'}, {'id': 2, 'name': 'apple ', 'count': 0, 'coordindate': '[]'}, {'id': 3, 'name': 'carrot ', 'count': 0, 'coordindate': '[]'}]
#    id     name     x_coord     y_coord
# 0   5  squash   260.143310  190.296941
# 1   2   apple   189.703435  195.316209
# 2   5  squash   131.487655  193.231612
# 3   3  carrot   444.177520  328.514940
# 4   5  squash   422.732640  328.909965
# 5   5  squash   459.999300   47.625808
# 6   5  squash   408.307620  328.341480

# %%
arr = np.array([1,2])
print(arr)
print(list(arr))
# Out:
# [1 2]
# [1, 2]

# %%
from urllib import request
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt

url = "https://themightiestkpk1.s3.amazonaws.com/train12124.jpg"

res = request.urlopen(url).read()
a
img = Image.open(BytesIO(res))
fig = plt.figure()
plt.imshow(img)
plt.show()

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=453x300 at 0x7FE510296550>

# %%
import os
for p,d,fs in os.walk('./train'):
    for f in fs:
        if ' ' in f:
            print(f)
